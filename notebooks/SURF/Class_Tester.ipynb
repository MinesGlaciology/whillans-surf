# %%
from stations import Station
import pandas as pd

evts_path = "/Users/sambrown04/Documents/SURF/Events/2011_2011Events2stas"

# %%
station1 = Station("la01",evts_path, 2011)

# %%
for i in range(1,11):
# Out:
#                     time  tide_height
# 0    2013-10-11 18:51:30          NaN
# 1    2013-10-11 19:01:30          NaN
# 2    2013-10-11 19:11:30          NaN
# 3    2013-10-11 19:21:30          NaN
# 4    2013-10-11 19:31:30          NaN
# ...                  ...          ...
# 4315 2013-11-10 18:01:30          NaN
# 4316 2013-11-10 18:11:30          NaN
# 4317 2013-11-10 18:21:30          NaN
# 4318 2013-11-10 18:31:30          NaN
# 4319 2013-11-10 18:41:30          NaN
#
# [4320 rows x 2 columns]
