# %%
# Sam Brown
# sam_brown@mines.edu
# June 11 2025
# Goal: Use the Day class to parse our data and store high and low tide events for each day, eventually creating a feature that identifies whcih kind of event it is and if the low tide event was skipped.
