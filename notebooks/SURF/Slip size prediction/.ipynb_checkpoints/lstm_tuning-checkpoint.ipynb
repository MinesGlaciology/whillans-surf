# %%
# Sam Brown
# sam_brown@mines.edu
# July 17
# Goal: Tune lstm model and produce interesting graphs regarding the nature of the lstms

import sys
sys.path.append("/Users/sambrown04/Documents/SURF/whillans-surf/notebooks/SURF")

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader, random_split, TensorDataset
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from models.slip_lstm import SlipLSTM

df = pd.read_csv("/Users/sambrown04/Documents/SURF/Preproc_data/10-18.csv", parse_dates=["start_time"])
df = df.iloc[500:3000] # NANS UNKNOWN CHECK AGAIN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 17
#      14 from sklearn.metrics import mean_squared_error
#      15 from sklearn.metrics import r2_score
# ---> 17 from models.slip_lstm import SlipLSTM
#      19 df = pd.read_csv("/Users/sambrown04/Documents/SURF/Preproc_data/10-18.csv", parse_dates=["start_time"])
#      20 df = df.iloc[500:3000]
#
# ModuleNotFoundError: No module named 'models.slip_lstm'
