# %%
# Sam Brown
# sam_brown@mines.edu
# July 17
# Goal: Tune lstm model and produce interesting graphs regarding the nature of the lstms

import sys
sys.path.append("/Users/sambrown04/Documents/SURF/whillans-surf/notebooks/SURF")

import torch
import torch.nn as nn

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader, random_split, TensorDataset
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from models.slip_lstm import SlipLSTM

df = pd.read_csv("/Users/sambrown04/Documents/SURF/Preproc_data/10-18.csv", parse_dates=["start_time"])
df = df.iloc[500:3000] # NANS UNKNOWN CHECK AGAIN

# %%
# Features and Target
X = df[['tide_height', 'tide_deriv', 'A_diurn', 'A_semidiurn', 'high_t_evt', 'time_since', 'sev_stds', 'pre-s_stds', 'form_fac']]
y = df['slip_size_standardized'].values.reshape(-1,1)

# Normalize features
x_scaler = StandardScaler()
X_scaled = x_scaler.fit_transform(X)

y_scaler = StandardScaler()
y_scaled = y_scaler.fit_transform(y)

# %%
def gen_sequences(X, y, seq_len):
    sequences = []
    targets = []

    for i in range(len(X) - seq_len):
        seq = X[i:i+seq_len]
        target = y[i+seq_len - 1][0] # Including the features of the last event when predicting last event slip size 
        sequences.append(seq)
        targets.append(target)

    X_seq = torch.tensor(np.array(sequences), dtype=torch.float32)
    y_seq = torch.tensor(np.array(targets), dtype=torch.float32).unsqueeze(1)

    return X_seq, y_seq

# %%
seq_lengths = range(1, 30, 1)
results = []

for seq_len in seq_lengths:

    print(f"running model for seq length {seq_len}")

    X_seq, y_seq = gen_sequences(X_scaled, y_scaled, seq_len)

    # Split into train and test
    X_train, X_val, y_train, y_val = train_test_split(
        X_seq, y_seq, test_size=0.2, shuffle=False  # no shuffle = time-aware
    )

    
    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=False)
    val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=32)

    model = SlipLSTM(input_size=X_seq.shape[2], hidden_size=64)

    loss_fn = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    for epoch in range(30):
        model.train()
        for xb, yb in train_loader:
            pred = model(xb)
            loss = loss_fn(pred, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()

    val_preds  = []
    val_targets = []
    
    with torch.no_grad():
        for xb, yb in val_loader:
            val_preds.append(model(xb).cpu())
            val_targets.append(yb.cpu())


        # Combine batches into single tensors
        val_preds = torch.cat(val_preds, dim=0).squeeze().numpy()
        val_targets = torch.cat(val_targets, dim=0).squeeze().numpy()

        # Metrics
        val_loss = loss_fn(torch.tensor(val_preds), torch.tensor(val_targets)).item()
        r2 = r2_score(val_targets, val_preds)
        results.append(r2)
            
    print(f"Final MSE for SEQ_LEN={seq_len}: {val_loss:.4f} \n R2 = {r2:.4f}")
# Out:
# Running model for seq length 1
# Final MSE for SEQ_LEN=1: 0.5578
#  R2 = 0.4528
# Running model for seq length 2
# Final MSE for SEQ_LEN=2: 0.4847
#  R2 = 0.5245
# Running model for seq length 3
# Final MSE for SEQ_LEN=3: 0.5085
#  R2 = 0.5011
# Running model for seq length 4
# Final MSE for SEQ_LEN=4: 0.6626
#  R2 = 0.3499
# Running model for seq length 5
# Final MSE for SEQ_LEN=5: 0.5422
#  R2 = 0.4668
# Running model for seq length 6
# Final MSE for SEQ_LEN=6: 0.4619
#  R2 = 0.5459
# Running model for seq length 7
# Final MSE for SEQ_LEN=7: 0.6256
#  R2 = 0.3849
# Running model for seq length 8
# Final MSE for SEQ_LEN=8: 0.5267
#  R2 = 0.4821
# Running model for seq length 9
# Final MSE for SEQ_LEN=9: 0.6166
#  R2 = 0.3937
# Running model for seq length 10
# Final MSE for SEQ_LEN=10: 0.5170
#  R2 = 0.4911
# Running model for seq length 11
# Final MSE for SEQ_LEN=11: 0.5963
#  R2 = 0.4130
# Running model for seq length 12
# Final MSE for SEQ_LEN=12: 0.4918
#  R2 = 0.5159
# Running model for seq length 13
# Final MSE for SEQ_LEN=13: 0.6020
#  R2 = 0.4074
# Running model for seq length 14
# Final MSE for SEQ_LEN=14: 0.5701
#  R2 = 0.4388
# Running model for seq length 15
# Final MSE for SEQ_LEN=15: 0.5822
#  R2 = 0.4267
# Running model for seq length 16
# Final MSE for SEQ_LEN=16: 0.4822
#  R2 = 0.5252
# Running model for seq length 17
# Final MSE for SEQ_LEN=17: 0.5214
#  R2 = 0.4866
# Running model for seq length 18
# Final MSE for SEQ_LEN=18: 0.5088
#  R2 = 0.4990
# Running model for seq length 19
# Final MSE for SEQ_LEN=19: 0.5325
#  R2 = 0.4757
# Running model for seq length 20
# Final MSE for SEQ_LEN=20: 0.5633
#  R2 = 0.4452
# Running model for seq length 21
# Final MSE for SEQ_LEN=21: 0.5676
#  R2 = 0.4410
# Running model for seq length 22
# Final MSE for SEQ_LEN=22: 0.6057
#  R2 = 0.4034
# Running model for seq length 23
# Final MSE for SEQ_LEN=23: 0.5175
#  R2 = 0.4903
# Running model for seq length 24
# Final MSE for SEQ_LEN=24: 0.4901
#  R2 = 0.5173
# Running model for seq length 25
# Final MSE for SEQ_LEN=25: 0.5066
#  R2 = 0.5004
# Running model for seq length 26
# Final MSE for SEQ_LEN=26: 0.5266
#  R2 = 0.4807
# Running model for seq length 27
# Final MSE for SEQ_LEN=27: 0.4716
#  R2 = 0.5350
# Running model for seq length 28
# Final MSE for SEQ_LEN=28: 0.6009
#  R2 = 0.4075
# Running model for seq length 29
# Final MSE for SEQ_LEN=29: 0.5246
#  R2 = 0.4827

# %%
plt.plot(seq_lengths, results)
plt.xlabel("Length of sequence fed into LSTM")
plt.ylabel("Model R^2")
plt.minorticks_on()

# %%
import matplotlib.pyplot as plt
