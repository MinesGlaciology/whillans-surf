# %%
# Sam Brown
# sam_brown@mines.edu
# Date 06/02\2025
# Goal: Explore/ confirm whether there is a connection between the days since last event and the tide height.


# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates

import my_lib.funcs

evts_path = "/Users/sambrown04/Documents/SURF/Events/2010_2010Events2stas"

# %%
# load events
events_list = my_lib.funcs.load_evt(evts_path)

# %%
pre_events = my_lib.funcs.preprocess_events(events_list)

# %%
pre_events[0].head()
# Out:
#       la01x     la02x     la04x     la05x     la06x     la07x     la08x  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.002548  0.000670  0.001023  0.001910  0.004177  0.003173  0.000389
# 2  0.001123  0.000361  0.004057  0.000782  0.002984  0.001622  0.000556
# 3  0.001361  0.002628  0.006945  0.002364  0.000883  0.000300  0.006129
# 4  0.000486  0.004988  0.007686  0.001503  0.002985  0.000761  0.002145
#
#       la09x     la10x  time_sec             time_dt
# 0  0.000000  0.000000       0.0 2010-11-18 23:03:00
# 1  0.000366  0.000678      15.0 2010-11-18 23:03:15
# 2  0.000731  0.002131      30.0 2010-11-18 23:03:30
# 3  0.002069  0.004544      45.0 2010-11-18 23:03:45
# 4  0.003407  0.001428      60.0 2010-11-18 23:04:00

# %%
# make new list of dataframes. With the days since last event and the time. Only include events in which a gz station is recording
