# %%
# Sam Brown
# sam_brown@mines.edu
# June 18
# Goal: Neural Net for predicting time until next event

# Directory
import sys
sys.path.append("/Users/sambrown04/Documents/SURF/whillans-surf/notebooks/SURF")

# Imports
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('averages_events_2011-13')
df = df.iloc[1:-1] # account for shift to get mins until

# %%
# Define features and target
X = df[['mins_since', 'tide_change', 'tide_height', 'h_event', 'form_factor', 'slip_severity', 'total_delta', 'pre_slip_area']]
y = df['mins_until'].values.reshape(-1,1)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = .2, random_state = 42)

# Standardize
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

y_train_scaled = scaler.fit_transform(y_train)
y_test_scaled = scaler.transform(y_test)

# Pytorch tensors 
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_scaled, dtype=torch.float32)

X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_scaled, dtype=torch.float32)

# %%
# Neural Net
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(8, 32)
        self.fc2 = nn.Linear(32, 16)
        self.fc3 = nn.Linear(16,1)

    def forward(self,x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x) # Regressing
        return x

# %%
model = Net()
criterion = nn.MSELoss() # Loss for regression
optimizer = optim.Adam(model.parameters(), lr = .01)

# %%
# Training loop
epochs = 200
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad() # Clears grad

    # Predictions and loss
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    # Backprop
    loss.backward()

    # Update params
    optimizer.step()
    
    if (epoch+1) % 20 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [20/200], Loss: 0.9095
# Epoch [40/200], Loss: 0.8113
# Epoch [60/200], Loss: 0.7241
# Epoch [80/200], Loss: 0.6645
# Epoch [100/200], Loss: 0.6250
# Epoch [120/200], Loss: 0.5895
# Epoch [140/200], Loss: 0.5647
# Epoch [160/200], Loss: 0.5404
# Epoch [180/200], Loss: 0.5236
# Epoch [200/200], Loss: 0.5078

# %%
# Eval
model.eval()
with torch.no_grad():
    y_pred_scaled = model(X_test_tensor)
    y_pred = scaler.inverse_transform(y_pred_scaled.numpy())
    y_test_orig = scaler.inverse_transform(y_test_tensor.numpy())

# predictions vs actual
print("\nPredictions vs Actual:")
for pred, actual in zip(y_pred.flatten(), y_test_orig.flatten()):
    print(f"Predicted: {pred:.2f}, Actual: {actual:.2f}")
# Out:
# Predictions vs Actual:
# Predicted: 1611.02, Actual: 1470.00
# Predicted: 832.22, Actual: 750.00
# Predicted: 1210.20, Actual: 870.75
# Predicted: 884.22, Actual: 660.00
# Predicted: 1966.05, Actual: 1319.25
# Predicted: 876.82, Actual: 515.00
# Predicted: 1394.90, Actual: 1475.75
# Predicted: 1563.86, Actual: 1395.00
# Predicted: 627.99, Actual: 606.50
# Predicted: 749.57, Actual: 633.25
# Predicted: 738.23, Actual: 776.50
# Predicted: 846.42, Actual: 900.50
# Predicted: 734.74, Actual: 824.25
# Predicted: 886.72, Actual: 1406.00
# Predicted: 940.62, Actual: 930.00
# Predicted: 834.95, Actual: 769.50
# Predicted: 946.74, Actual: 757.00
# Predicted: 1288.52, Actual: 1443.75
# Predicted: 773.67, Actual: 495.00
# Predicted: 779.31, Actual: 1270.00
# Predicted: 768.23, Actual: 928.75
# Predicted: 1489.84, Actual: 1510.00
# Predicted: 778.64, Actual: 625.00
# Predicted: 1010.47, Actual: 787.50
# Predicted: 787.59, Actual: 760.00
# Predicted: 987.03, Actual: 1395.00
# Predicted: 1381.27, Actual: 1030.00
# Predicted: 726.16, Actual: 598.50
# Predicted: 772.90, Actual: 878.00
# Predicted: 875.79, Actual: 800.00
# Predicted: 846.90, Actual: 1840.25
# Predicted: 1336.37, Actual: 600.00
# Predicted: 913.05, Actual: 1014.00
# Predicted: 709.91, Actual: 777.50
# Predicted: 775.40, Actual: 920.00
# Predicted: 934.11, Actual: 579.00
# Predicted: 408.00, Actual: 785.00
# Predicted: 978.35, Actual: 1345.00
# Predicted: 1024.83, Actual: 975.00
# Predicted: 684.44, Actual: 1795.00
# Predicted: 899.29, Actual: 602.75
# Predicted: 1426.50, Actual: 1494.00
# Predicted: 1113.68, Actual: 1325.00
# Predicted: 1140.41, Actual: 565.00
# Predicted: 763.45, Actual: 749.75
# Predicted: 664.22, Actual: 730.25
# Predicted: 729.50, Actual: 1483.75
# Predicted: 749.57, Actual: 500.00
# Predicted: 908.68, Actual: 852.50
# Predicted: 690.93, Actual: 917.75
# Predicted: 755.44, Actual: 885.00
# Predicted: 1126.44, Actual: 658.25
# Predicted: 808.58, Actual: 625.00
# Predicted: 831.82, Actual: 833.75
# Predicted: 1153.92, Actual: 1504.75
# Predicted: 1353.16, Actual: 1437.00
# Predicted: 796.06, Actual: 635.00
# Predicted: 1449.38, Actual: 1527.25
# Predicted: 782.78, Actual: 845.00
# Predicted: 911.41, Actual: 845.00
# Predicted: 749.57, Actual: 508.75
# Predicted: 1121.41, Actual: 1465.50
# Predicted: 800.66, Actual: 1297.50
# Predicted: 607.43, Actual: 1350.00
# Predicted: 889.55, Actual: 541.00
# Predicted: 1329.03, Actual: 670.25
# Predicted: 796.44, Actual: 545.00
# Predicted: 769.65, Actual: 1368.75
# Predicted: 1135.29, Actual: 1469.25
# Predicted: 974.74, Actual: 1462.00
# Predicted: 696.77, Actual: 740.75
# Predicted: 1176.36, Actual: 808.50
# Predicted: 899.71, Actual: 665.00
# Predicted: 644.64, Actual: 658.00
# Predicted: 980.26, Actual: 1448.25
# Predicted: 878.84, Actual: 1269.75
# Predicted: 1354.05, Actual: 1516.50
# Predicted: 565.97, Actual: 625.00
# Predicted: 932.55, Actual: 1170.00
# Predicted: 934.01, Actual: 959.00
# Predicted: 1148.46, Actual: 660.00
# Predicted: 903.46, Actual: 1435.00
# Predicted: 875.70, Actual: 780.00
# Predicted: 481.86, Actual: 827.50
# Predicted: 982.85, Actual: 900.00
# Predicted: 719.72, Actual: 576.00
# Predicted: 823.29, Actual: 858.75
# Predicted: 786.76, Actual: 1418.75
# Predicted: 899.32, Actual: 1337.75
# Predicted: 809.75, Actual: 790.00
# Predicted: 1031.83, Actual: 1090.00
# Predicted: 1066.28, Actual: 1486.25
# Predicted: 1024.10, Actual: 1075.00
# Predicted: 953.47, Actual: 935.00
# Predicted: 881.74, Actual: 790.00
# Predicted: 757.11, Actual: 610.00
# Predicted: 1443.33, Actual: 1441.25
# Predicted: 1357.23, Actual: 1380.00
# Predicted: 822.85, Actual: 842.50
# Predicted: 885.30, Actual: 849.50
# Predicted: 624.68, Actual: 765.00
# Predicted: 778.64, Actual: 728.00
# Predicted: 899.65, Actual: 971.50
# Predicted: 772.71, Actual: 1333.50
# Predicted: 750.44, Actual: 670.50
# Predicted: 868.91, Actual: 707.75
# Predicted: 825.98, Actual: 764.25
# Predicted: 993.61, Actual: 1460.00
# Predicted: 1089.96, Actual: 988.25
# Predicted: 745.42, Actual: 865.00
# Predicted: 888.31, Actual: 825.00
# Predicted: 570.64, Actual: 1383.50
# Predicted: 772.01, Actual: 577.75
# Predicted: 916.34, Actual: 860.75
# Predicted: 752.79, Actual: 528.25
# Predicted: 1164.01, Actual: 1354.50
# Predicted: 946.09, Actual: 976.50
# Predicted: 782.89, Actual: 925.00
# Predicted: 1277.59, Actual: 1365.25
# Predicted: 1050.57, Actual: 565.00
# Predicted: 1207.05, Actual: 1428.50
# Predicted: 932.79, Actual: 520.00
# Predicted: 903.00, Actual: 825.00
# Predicted: 1106.85, Actual: 758.50
# Predicted: 900.73, Actual: 810.00
# Predicted: 903.56, Actual: 875.25
# Predicted: 1116.41, Actual: 577.75
# Predicted: 1154.33, Actual: 945.00
# Predicted: 1055.50, Actual: 579.00
# Predicted: 875.77, Actual: 874.75
# Predicted: 1074.30, Actual: 1000.00
# Predicted: 884.26, Actual: 868.25
# Predicted: 970.36, Actual: 530.00
# Predicted: 706.51, Actual: 1330.00
# Predicted: 724.46, Actual: 800.00
# Predicted: 1104.70, Actual: 635.00
# Predicted: 937.47, Actual: 545.00
# Predicted: 960.02, Actual: 1492.25
# Predicted: 814.87, Actual: 712.25
# Predicted: 813.76, Actual: 807.25
# Predicted: 823.30, Actual: 883.00
# Predicted: 688.48, Actual: 635.00
# Predicted: 654.59, Actual: 680.00
# Predicted: 1077.41, Actual: 497.75
# Predicted: 648.03, Actual: 660.25
# Predicted: 972.22, Actual: 1095.00
# Predicted: 1451.77, Actual: 551.75
# Predicted: 736.97, Actual: 773.75
# Predicted: 990.00, Actual: 943.25
# Predicted: 1077.92, Actual: 1315.00
# Predicted: 864.83, Actual: 870.00
# Predicted: 982.35, Actual: 880.00
# Predicted: 923.09, Actual: 1270.25
# Predicted: 1076.92, Actual: 1008.00
# Predicted: 1284.41, Actual: 1430.00
# Predicted: 973.77, Actual: 580.00
# Predicted: 1413.06, Actual: 1241.50
# Predicted: 668.99, Actual: 786.00
# Predicted: 748.34, Actual: 675.00
# Predicted: 828.60, Actual: 675.00
# Predicted: 642.79, Actual: 755.00
# Predicted: 1395.76, Actual: 855.00
# Predicted: 1342.55, Actual: 1450.00
# Predicted: 790.76, Actual: 935.00
# Predicted: 688.30, Actual: 761.00
# Predicted: 889.76, Actual: 845.00
# Predicted: 1062.52, Actual: 1191.50
# Predicted: 782.48, Actual: 615.00
# Predicted: 993.51, Actual: 1202.25
# Predicted: 1442.03, Actual: 1200.00
# Predicted: 1097.48, Actual: 1365.00
# Predicted: 893.39, Actual: 1390.00
# Predicted: 1097.88, Actual: 1176.25
# Predicted: 1064.84, Actual: 695.00
# Predicted: 1071.30, Actual: 1115.75
# Predicted: 641.85, Actual: 862.75
# Predicted: 1081.75, Actual: 1254.50
# Predicted: 1403.31, Actual: 1532.50
# Predicted: 493.00, Actual: 1205.00
# Predicted: 1130.36, Actual: 1453.75
# Predicted: 1054.17, Actual: 1255.00
# Predicted: 1070.67, Actual: 1486.50
# Predicted: 1215.18, Actual: 1285.00
# Predicted: 786.45, Actual: 567.50
# Predicted: 790.56, Actual: 726.00
# Predicted: 1462.52, Actual: 1395.00
# Predicted: 848.12, Actual: 869.50
# Predicted: 871.44, Actual: 972.25
# Predicted: 856.32, Actual: 542.75
# Predicted: 864.13, Actual: 755.00
# Predicted: 825.02, Actual: 1487.50
# Predicted: 971.84, Actual: 646.00
# Predicted: 896.16, Actual: 695.00
# Predicted: 761.46, Actual: 690.75
# Predicted: 1252.69, Actual: 1490.50
# Predicted: 806.09, Actual: 576.00
# Predicted: 883.53, Actual: 690.00
# Predicted: 1417.96, Actual: 579.75
# Predicted: 1049.87, Actual: 1435.00
# Predicted: 892.34, Actual: 1350.25
# Predicted: 922.61, Actual: 940.75
# Predicted: 841.02, Actual: 1424.25
# Predicted: 559.78, Actual: 680.50
# Predicted: 1637.44, Actual: 1439.25
# Predicted: 773.34, Actual: 1415.00
# Predicted: 822.92, Actual: 1469.25
# Predicted: 1124.91, Actual: 710.00
# Predicted: 669.71, Actual: 1385.00
# Predicted: 833.95, Actual: 797.50
# Predicted: 786.58, Actual: 741.50
# Predicted: 946.07, Actual: 975.00
# Predicted: 2534.75, Actual: 762.00
# Predicted: 2030.83, Actual: 1335.00
# Predicted: 886.15, Actual: 924.25
# Predicted: 1395.72, Actual: 710.00
# Predicted: 958.81, Actual: 624.25
# Predicted: 882.91, Actual: 560.00
# Predicted: 1035.40, Actual: 726.00
# Predicted: 705.40, Actual: 1546.25
# Predicted: 924.23, Actual: 1455.00
# Predicted: 749.57, Actual: 564.75
# Predicted: 794.59, Actual: 730.00
# Predicted: 807.10, Actual: 770.00
# Predicted: 864.33, Actual: 1469.50
# Predicted: 960.79, Actual: 562.50
# Predicted: 879.37, Actual: 700.00
# Predicted: 700.06, Actual: 1185.00
# Predicted: 806.23, Actual: 1400.00
# Predicted: 953.03, Actual: 1375.00
# Predicted: 686.76, Actual: 635.50
# Predicted: 980.18, Actual: 1196.00
# Predicted: 875.48, Actual: 875.00
# Predicted: 1050.67, Actual: 1440.00
# Predicted: 857.30, Actual: 602.75
# Predicted: 792.13, Actual: 865.00
# Predicted: 714.39, Actual: 1495.50
# Predicted: 971.87, Actual: 781.50
# Predicted: 897.54, Actual: 1143.00
# Predicted: 1324.31, Actual: 1392.00
# Predicted: 975.01, Actual: 955.00
# Predicted: 726.34, Actual: 729.25
# Predicted: 669.51, Actual: 695.00
# Predicted: 926.04, Actual: 1085.00
# Predicted: 614.48, Actual: 699.00
# Predicted: 732.65, Actual: 785.00
# Predicted: 832.94, Actual: 1445.00
# Predicted: 936.62, Actual: 633.25
# Predicted: 950.79, Actual: 1075.00
# Predicted: 675.05, Actual: 584.75
# Predicted: 766.72, Actual: 769.00
# Predicted: 904.63, Actual: 929.25
# Predicted: 632.01, Actual: 671.75
# Predicted: 583.43, Actual: 656.00
# Predicted: 887.15, Actual: 780.00
# Predicted: 684.22, Actual: 610.00
# Predicted: 884.90, Actual: 810.00
# Predicted: 1062.29, Actual: 970.50
# Predicted: 1031.59, Actual: 985.00
# Predicted: 801.28, Actual: 515.00
# Predicted: 806.99, Actual: 798.75
# Predicted: 726.78, Actual: 783.00
# Predicted: 1400.94, Actual: 1420.00
# Predicted: 1018.85, Actual: 830.00
# Predicted: 857.90, Actual: 595.00
# Predicted: 749.57, Actual: 539.50
# Predicted: 829.28, Actual: 880.00
# Predicted: 686.42, Actual: 980.00
# Predicted: 1233.68, Actual: 1505.75
# Predicted: 884.97, Actual: 840.00
# Predicted: 924.65, Actual: 805.00
# Predicted: 723.86, Actual: 552.75
# Predicted: 1064.62, Actual: 570.75
# Predicted: 895.76, Actual: 915.00
# Predicted: 970.39, Actual: 916.25
# Predicted: 1144.26, Actual: 1327.25
# Predicted: 780.48, Actual: 750.00
# Predicted: 1725.09, Actual: 1426.25
# Predicted: 887.11, Actual: 897.50
# Predicted: 829.10, Actual: 855.00
# Predicted: 745.82, Actual: 530.00
# Predicted: 698.50, Actual: 605.00
# Predicted: 670.65, Actual: 711.25
# Predicted: 984.29, Actual: 1185.50
# Predicted: 1243.41, Actual: 1379.00
# Predicted: 1099.64, Actual: 1700.00
# Predicted: 1095.48, Actual: 736.50
# Predicted: 699.62, Actual: 871.50
# Predicted: 1053.13, Actual: 1560.00
# Predicted: 815.13, Actual: 1765.00
# Predicted: 800.02, Actual: 865.50
# Predicted: 685.24, Actual: 745.00
# Predicted: 858.02, Actual: 800.00
# Predicted: 1008.98, Actual: 513.00
# Predicted: 923.19, Actual: 1415.00
# Predicted: 791.29, Actual: 735.50
# Predicted: 1052.80, Actual: 1010.00
# Predicted: 760.18, Actual: 820.00
# Predicted: 857.29, Actual: 628.75
# Predicted: 1230.92, Actual: 640.00
# Predicted: 826.55, Actual: 840.25
# Predicted: 858.97, Actual: 858.75
# Predicted: 1147.52, Actual: 1430.00
# Predicted: 822.67, Actual: 700.00
# Predicted: 874.93, Actual: 970.00
# Predicted: 793.74, Actual: 1552.50
# Predicted: 988.66, Actual: 1475.00
# Predicted: 1111.37, Actual: 941.75
# Predicted: 963.12, Actual: 936.00
# Predicted: 913.93, Actual: 1380.25
# Predicted: 1035.50, Actual: 1000.00
# Predicted: 1197.69, Actual: 657.00
# Predicted: 1280.66, Actual: 1433.00
# Predicted: 927.97, Actual: 941.25
# Predicted: 1011.85, Actual: 994.75
# Predicted: 847.64, Actual: 1464.25
# Predicted: 949.14, Actual: 610.00
# Predicted: 769.50, Actual: 1445.75
# Predicted: 977.38, Actual: 900.00
# Predicted: 903.95, Actual: 925.00
# Predicted: 1033.48, Actual: 726.50
# Predicted: 770.49, Actual: 825.00
# Predicted: 870.84, Actual: 905.00
# Predicted: 857.11, Actual: 611.00
# Predicted: 958.63, Actual: 877.50
# Predicted: 778.09, Actual: 615.75
# Predicted: 726.42, Actual: 610.00
# Predicted: 952.34, Actual: 1454.75
# Predicted: 754.30, Actual: 855.00
# Predicted: 643.61, Actual: 778.75

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test_orig, y_pred)
print(r2)
# Out:
# -0.050896644592285156

# %%
# Very Bad!
