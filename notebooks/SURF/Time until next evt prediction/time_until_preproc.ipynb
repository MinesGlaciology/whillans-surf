# %%
# Need to explore using the data for gps and tides between the events. More useful as a feature for predicting how long until the next evt
# We will want to have form factor between the events as a feature, and slope of movement between events.
# Also could take amplitude coefficients used in form factor calc as features
