# %%
# Sam Brown
# sam_brown@mines.edu
# July 30
# Goal: take the preprocessed inter event positional data and make features based off of that

import sys
sys.path.append("/Users/sambrown/Documents/SURF/whillans-surf/notebooks/SURF")

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

import my_lib.funcs

# %%
df_2010 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2010_2010Events2stas")
df_2011 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2011_2011Events2stas")
df_2012 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2012_2012Events2stas")
df_2013 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2013_2013Events2stas")
df_2014 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2014_2014Events2stas")
df_2015 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2015_2015Events2stas")
df_2016 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2016_2016Events2stas")
df_2017 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2017_2017Events2stas")
df_2018 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2018_2018Events2stas")
df_2019 = my_lib.funcs.load_evt("/Users/sambrown/Documents/SURF/Events/2019_2019Events2stas")

# One Large list
all_dfs = (
    df_2010 
    + df_2011 
    + df_2012 + df_2013 +
    df_2014 + df_2015 + df_2016 + df_2017 + df_2018 
)

# %%
dfs_sorted = sorted(all_dfs, key=lambda df: df['time'].iloc[0])

# %%
dfs_sorted[0].head()
# Out:
#    Unnamed: 0                 time  la01x  la01y  la01z  la01res  la01res_avg  \
# 0        3701  2010-01-01 15:25:30    NaN    NaN    NaN      NaN          NaN
# 1        3702  2010-01-01 15:25:45    NaN    NaN    NaN      NaN          NaN
# 2        3703  2010-01-01 15:26:00    NaN    NaN    NaN      NaN          NaN
# 3        3704  2010-01-01 15:26:15    NaN    NaN    NaN      NaN          NaN
# 4        3705  2010-01-01 15:26:30    NaN    NaN    NaN      NaN          NaN
#
#    la02x  la02y  la02z  ...  ws05res  ws05res_avg          slw1x  \
# 0    NaN    NaN    NaN  ...      NaN          NaN -278020.375213
# 1    NaN    NaN    NaN  ...      NaN          NaN -278020.369088
# 2    NaN    NaN    NaN  ...      NaN          NaN -278020.375350
# 3    NaN    NaN    NaN  ...      NaN          NaN -278020.362223
# 4    NaN    NaN    NaN  ...      NaN          NaN -278020.376233
#
#            slw1y    slw1z   slw1res  slw1res_avg  sum_res_avg    ressum  event
# 0 -560366.976898  91.8077  0.082613     0.066715     0.075662  0.101509    1.0
# 1 -560366.982976  91.8367  0.082613     0.066715     0.075662  0.101509    1.0
# 2 -560366.976492  91.7943  0.082613     0.066715     0.075662  0.101509    1.0
# 3 -560366.984356  91.8159  0.082613     0.066715     0.075662  0.101509    1.0
# 4 -560366.979431  91.8127  0.082613     0.066715     0.075662  0.101509    1.0
#
# [5 rows x 65 columns]

# %%
interdf1 = pd.read_csv("/Users/sambrown/Documents/SURF/Inter_events_dat/Event0.csv")

# %%
interdf1.columns
# Out:
# Index(['la05_x', 'la05_y', 'la05_z', 'time', 'la04_x', 'la04_y', 'la04_z',
#        'la10_x', 'la10_y', 'la10_z', 'la06_x', 'la06_y', 'la06_z', 'la07_x',
#        'la07_y', 'la07_z', 'la02_x', 'la02_y', 'la02_z', 'ws05_x', 'ws05_y',
#        'ws05_z', 'la01_x', 'la01_y', 'la01_z', 'ws04_x', 'ws04_y', 'ws04_z',
#        'slw1_x', 'slw1_y', 'slw1_z', 'la09_x', 'la09_y', 'la09_z', 'la08_x',
#        'la08_y', 'la08_z'],
#       dtype='object')
