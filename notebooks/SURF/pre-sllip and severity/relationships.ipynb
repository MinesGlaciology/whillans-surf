# %%
# Sam Brown
# sam_brown@mines.edu
# July 13
# Goal: Explore relationships between slip severity, high tide events, precursor slip, and slip size

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/sambrown04/Documents/SURF/Preproc_data/10-18.csv")

# %%
df.head()
# Out:
#    tide_deriv  form_fac  time_since  slip_size_standardized  high_t_evt  \
# 0    0.024640  3.782138         NaN               -1.931350           1
# 1   -0.232954  3.782138      512.50               -2.792976           0
# 2   -0.087155  3.126144     1037.75               -0.793920           1
# 3    0.138536  2.571349     1382.75               -0.838199           1
# 4   -0.484872  2.571349      445.00               -1.435594           0
#
#             start_time  sev_stds  pre-s_stds  tide_height  inter_form_Fac  \
# 0  2010-01-01 15:25:00 -0.270159   -0.831226   108.956127             NaN
# 1  2010-01-01 23:58:00 -0.668066   -0.739235  -126.423818        3.878220
# 2  2010-01-02 17:15:00 -0.180573    0.594509    94.249899        3.003587
# 3  2010-01-03 16:18:00 -0.209510   -0.773764    65.040870        2.356065
# 4  2010-01-03 23:43:00 -0.204831   -0.806752   -57.608298        2.632244
#
#       A_diurn  A_semidiurn
# 0         NaN          NaN
# 1  112.390988    28.980043
# ...
