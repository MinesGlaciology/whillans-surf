# %%
# Sam Brown
# sam_brown@mines.edu
# June 9, 2025
# Goal: Form and save a dataframe that will be used to train neural net


# One neural net/ dataset for events averaged out and one dataset for individual instances of of stations

# first dataset: gz stations: 2011 to 2013
# columns = Slip impulsivity, time since last event, slip length, tide height, form factor, tide derivative...?
# Start with
