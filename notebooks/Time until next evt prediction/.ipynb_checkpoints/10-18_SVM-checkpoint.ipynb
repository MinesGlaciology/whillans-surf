# %%
# Sam Brown
# Sam_brown@mines.edu
# July 11
# Goal: Explore more generalized models for predicting the time until next event

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Ideas
# Predicting the time bracket until the event. 
# Histogram of inter event time shows two large "humps" 
# Good splitting spot is 1100 minutes

df = pd.read_csv("/Users/sambrown04/Documents/SURF/Preproc_data/upd10-18.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  tide_deriv  form_fac  time_since  slip_size_standardized  \
# 0           0    0.024640  3.782138         NaN               -1.931350
# 1           1   -0.232954  3.782138      512.50               -2.792976
# 2           2   -0.087155  3.126144     1037.75               -0.793920
# 3           3    0.138536  2.571349     1382.75               -0.838199
# 4           4   -0.484872  2.571349      445.00               -1.435594
#
#    high_t_evt           start_time  sev_stds  pre-s_stds  tide_height  \
# 0           1  2010-01-01 15:25:00 -0.270159   -0.831226   108.956127
# 1           0  2010-01-01 23:58:00 -0.668066   -0.739235  -126.423818
# 2           1  2010-01-02 17:15:00 -0.180573    0.594509    94.249899
# 3           1  2010-01-03 16:18:00 -0.209510   -0.773764    65.040870
# 4           0  2010-01-03 23:43:00 -0.204831   -0.806752   -57.608298
#
#    inter_form_Fac     A_diurn  A_semidiurn  disp_standardized  \
# ...

# %%
plt.hist(df['time_since'], bins = 1200)
plt.xlim([0,2000])
# Out:
# (0.0, 2000.0)

# %%
# Column for 2 options
df['time_bracket'] = (df['time_since'] > 1100).astype(int)

conditions = [
    df['time_since'] <= 750,
    (df['time_since'] > 750) & (df['time_since'] <= 1100),
    df['time_since'] > 1100
]
choices = [0, 1, 2]

# Column for three options
df['time_bracket3'] = np.select(conditions, choices)

# %%
df = df[1:-1]
df.head()
# Out:
#    Unnamed: 0  tide_deriv  form_fac  time_since  slip_size_standardized  \
# 1           1   -0.232954  3.782138      512.50               -2.792976
# 2           2   -0.087155  3.126144     1037.75               -0.793920
# 3           3    0.138536  2.571349     1382.75               -0.838199
# 4           4   -0.484872  2.571349      445.00               -1.435594
# 5           5    0.032944  2.023008      912.75               -1.714496
#
#    high_t_evt           start_time  sev_stds  pre-s_stds  tide_height  \
# 1           0  2010-01-01 23:58:00 -0.668066   -0.739235  -126.423818
# 2           1  2010-01-02 17:15:00 -0.180573    0.594509    94.249899
# 3           1  2010-01-03 16:18:00 -0.209510   -0.773764    65.040870
# 4           0  2010-01-03 23:43:00 -0.204831   -0.806752   -57.608298
# 5           1  2010-01-04 14:56:00 -0.485152   -0.800717    23.343183
#
#    inter_form_Fac     A_diurn  A_semidiurn  disp_standardized  \
# ...

# %%
feat_cols = [
    'tide_deriv', 'form_fac', 'sev_stds', 'pre-s_stds',
    'tide_height', 'inter_form_Fac', 'A_diurn', 'A_semidiurn',
    'r2_standardized', 'slope_standardized'
]

# drop rows where the target is missing
df = df[~df['time_bracket'].isna()]

# features target
X = df[feat_cols].to_numpy()
y = df['time_bracket'].to_numpy()

# split (keep class balance)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# pipeline: impute scale then svm
svm_pipe = Pipeline([
    ("impute", SimpleImputer(strategy="median")),   # handle NaNs
    ("scale", StandardScaler()),
    ("svm", SVC(probability=True))                  # set class_weight="balanced" if needed (Not needed in this case confusion matrix looks healthy)
])

# hyperparams to try
svm_params = {
    "svm__kernel": ["rbf", "linear"],
    "svm__C": [0.1, 1, 10],
    "svm__gamma": ["scale", 0.1, 0.01]  # used for rbf; ignored for linear
}

# CV setup
cv_setup = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# grid search
svm_grid = GridSearchCV(
    estimator=svm_pipe,
    param_grid=svm_params,
    cv=cv_setup,
    scoring="accuracy",
    n_jobs=-1
)

# fit
svm_grid.fit(X_train, y_train)

# results
print("Best params:", svm_grid.best_params_)
test_preds = svm_grid.predict(X_test)
print("Accuracy:", accuracy_score(y_test, test_preds))
print("classification report:\n", classification_report(y_test, test_preds))
cm = confusion_matrix(y_test3, test_preds3)
print("Confusion matrix:\n", cm)
# Out:
# Best params: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Accuracy: 0.9606557377049181
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       554
#            1       0.96      0.94      0.95       361
#
#     accuracy                           0.96       915
#    macro avg       0.96      0.96      0.96       915
# weighted avg       0.96      0.96      0.96       915
#
# Confusion matrix:
#  [[216  27   5]
#  [ 19 269  18]
#  [  1  19 341]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# First case: 2 classes
labels2 = ["≤1100", ">1100"]
cm2 = confusion_matrix(y_test, test_preds, labels=[0, 1])

disp2 = ConfusionMatrixDisplay(confusion_matrix=cm2, display_labels=labels2)
disp2.plot(cmap="Blues", values_format="d", text_kw={"fontsize": 25})  # bigger numbers
plt.title("Confusion Matrix", fontsize=20)
plt.xlabel("Predicted Label (min)", fontsize=20)
plt.ylabel("True Label (min)", fontsize=20)
plt.xticks(fontsize=16)  # bigger x-ticks
plt.yticks(fontsize=16, rotation=90)  # bigger y-ticks
plt.savefig("conf.png", dpi=300, bbox_inches="tight", pad_inches=0.5)

# Second case: 3 classes
labels3 = ["≤750", "751–1100", ">1100"]
cm3 = confusion_matrix(y_test3, test_preds3, labels=[0, 1, 2])

disp3 = ConfusionMatrixDisplay(confusion_matrix=cm3, display_labels=labels3)
disp3.plot(cmap="Greens", values_format="d", text_kw={"fontsize": 25})  # bigger numbers
plt.title("Confusion Matrix", fontsize=20)
plt.xlabel("Predicted Label (min)", fontsize=20)
plt.ylabel("True Label (min)", fontsize=20)
plt.xticks(fontsize=16)  # bigger x-ticks
plt.yticks(fontsize=16, rotation=90)  # bigger y-ticks
plt.savefig("conf2.png", dpi=300, bbox_inches="tight", pad_inches=0.5)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay

# First case: 2 classes
labels2 = ["≤1100", ">1100"]  # matches how you defined time_bracket
cm2 = confusion_matrix(y_test, test_preds, labels=[0, 1])

disp2 = ConfusionMatrixDisplay(confusion_matrix=cm2, display_labels=labels2)
disp2.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix", fontsize = 20)
plt.xlabel("Predicted Label (Minutes)", fontsize = 20)
plt.ylabel("True Label (Minutes)", fontsize = 20)
plt.show()

# Second case: 3 classes
# Prepare new y with 3-class target
y3 = df['time_bracket3'].to_numpy()
X_train3, X_test3, y_train3, y_test3 = train_test_split(
    X, y3, test_size=0.2, stratify=y3, random_state=42
)

svm_grid.fit(X_train3, y_train3)
test_preds3 = svm_grid.predict(X_test3)

labels3 = ["≤750", "751–1100", ">1100"]
cm3 = confusion_matrix(y_test3, test_preds3, labels=[0, 1, 2])

disp3 = ConfusionMatrixDisplay(confusion_matrix=cm3, display_labels=labels3)
disp3.plot(cmap="Greens", values_format="d")
plt.title("Confusion Matrix", fontsize = 20)
plt.xlabel("Predicted Label (Minutes)", fontsize = 20)
plt.ylabel("True Label (Minutes", fontsize = 20)
plt.show()
